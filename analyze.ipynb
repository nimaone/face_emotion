# %%
import pandas as pd
import pickle
from spike import config as cfg

# %%
# Read dictionary pkl file
with open(cfg.dict_path, 'rb') as fp:
    face = pickle.load(fp)
    print('Person dictionary')
    # print(person)
# Out:
# Person dictionary

# %%
df =pd.DataFrame.from_dict(face,orient='index')
df
# Out:
#                                                  path     angry      fear  \
# 0   ./customDataset/sohrabi/train/neutral_crop/fac...  0.025246  0.241871
# 1   ./customDataset/sohrabi/train/neutral_crop/fac...  0.019153  0.355637
# 2   ./customDataset/sohrabi/train/neutral_crop/fac...  0.024291  0.017876
# 3   ./customDataset/sohrabi/train/neutral_crop/fac...  0.023504  0.229442
# 4   ./customDataset/sohrabi/train/neutral_crop/fac...  0.007764  0.019707
# ..                                                ...       ...       ...
# 70  ./customDataset/sohrabi/train/neutral_crop/fac...  0.016837  0.066944
# 71  ./customDataset/sohrabi/train/neutral_crop/fac...  0.036735  0.268878
# 72  ./customDataset/sohrabi/train/neutral_crop/fac...  0.006013  0.076201
# 73  ./customDataset/sohrabi/train/neutral_crop/fac...  0.032982  0.050631
# 74  ./customDataset/sohrabi/train/neutral_crop/fac...  0.029856  0.168674
#
#        happy   neutral       sad  surprise
# ...

# %%
# v3
#               precision    recall  f1-score   support

#        angry       0.57      0.62      0.59      1069
#         fear       0.47      0.34      0.39      1024
#        happy       0.87      0.82      0.84      1774
#      neutral       0.58      0.63      0.60      1233
#          sad       0.49      0.50      0.49      1247
#     surprise       0.69      0.83      0.75       831

#     accuracy                           0.63      7178
#    macro avg       0.61      0.62      0.61      7178
# weighted avg       0.63      0.63      0.63      7178

# %%
# v4
#               precision    recall  f1-score   support

#        angry       0.56      0.59      0.57      1069
#         fear       0.46      0.36      0.40      1024
#        happy       0.88      0.80      0.84      1774
#      neutral       0.56      0.60      0.58      1233
#          sad       0.47      0.51      0.49      1247
#     surprise       0.70      0.81      0.75       831

#     accuracy                           0.62      7178
#    macro avg       0.60      0.61      0.61      7178
# weighted avg       0.62      0.62      0.62      7178

# %%
# model_3_v1
#               precision    recall  f1-score   support
#        angry       0.59      0.60      0.60      1069
#         fear       0.47      0.43      0.45      1024
#        happy       0.87      0.84      0.85      1774
#      neutral       0.60      0.59      0.59      1233
#          sad       0.50      0.51      0.50      1247
#     surprise       0.71      0.82      0.76       831

#     accuracy                           0.64      7178
#    macro avg       0.62      0.63      0.63      7178
# weighted avg       0.64      0.64      0.64      7178

# %%
# model_3_v1_trainval,,,,,,train2
#               precision    recall  f1-score   support

#        angry       0.57      0.65      0.61      1069
#         fear       0.47      0.45      0.46      1024
#        happy       0.89      0.81      0.85      1774
#      neutral       0.61      0.58      0.60      1233
#          sad       0.50      0.50      0.50      1247
#     surprise       0.71      0.82      0.76       831

#     accuracy                           0.64      7178
#    macro avg       0.63      0.64      0.63      7178
# weighted avg       0.65      0.64      0.64      7178

# %%
# !python train.py
